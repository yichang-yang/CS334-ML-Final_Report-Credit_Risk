# %%
from imblearn.over_sampling import SMOTE
from sklearn import model_selection, preprocessing
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.metrics import roc_auc_score, plot_roc_curve, confusion_matrix, roc_curve, classification_report, fbeta_score, accuracy_score

# %%
PCA_xTrain = pd.read_csv('PCA_xTrain.csv')
PCA_xTest = pd.read_csv('PCA_xTest.csv')
yTrain = pd.read_csv('yTrain.csv')
yTest = pd.read_csv('yTest.csv')

# %%
model = LogisticRegression(max_iter = 1000)
model.fit(PCA_xTrain, np.ravel(yTrain))
y_hat = model.predict(PCA_xTrain)

# %%
accuracy_score(yTrain, y_hat)
# Out:
# 0.5389728096676737

# %%
plot_roc_curve(model, PCA_xTrain, yTrain)

# %%
#F Beta score
fbeta_score(yTrain, y_hat, beta=0.5)
# Out:
# 0.7474589620038078

# %%
confusion_matrix(yTrain, y_hat)
# Out:
# array([[13314, 16307],
#        [56941, 72318]])

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB

# %%
model = GaussianNB()
model.fit(PCA_xTrain, np.ravel(yTrain))
y_hat = model.predict(PCA_xTrain)

# %%
accuracy_score(yTrain, y_hat)
# Out:
# 0.8126007049345418

# %%
plot_roc_curve(model, PCA_xTrain, yTrain)

# %%
#F Beta score
fbeta_score(yTrain, y_hat, beta=0.5)
# Out:
# 0.8448511746954434

# %%
confusion_matrix(yTrain, y_hat)
# Out:
# array([[    44,  29577],
#        [   197, 129062]])
